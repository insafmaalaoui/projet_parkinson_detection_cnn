# %%
import mlflow
from src.models.training import train_and_log

# %%
# paramètres
EPOCHS = 20
BATCH_SIZE = 16
LR = 1e-4
res = train_and_log(model_name="cnn_parkinson", epochs=EPOCHS, batch_size=BATCH_SIZE, lr=LR)
print("Training finished. Results:", res)

# %%
# Pour lancer le serveur MLflow localement (n'exécute pas via notebook si tu veux)
# Dans un terminal: mlflow ui --port 5000
print("Lancer dans un terminal: mlflow ui --port 5000")
